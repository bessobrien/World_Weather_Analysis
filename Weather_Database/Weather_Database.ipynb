# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities=[]

# ID the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
## Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b86ed79d889c181e845cf1b8664d00bb

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Ceate an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | kontagora
# Processing Record 3 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | chuy
# Processing Record 8 of Set 1 | geraldton
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | afsin
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | the valley
# Processing Record 14 of Set 1 | kedrovyy
# Processing Record 15 of Set 1 | waddan
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 20 of Set 1 | adet
# Processing Record 21 of Set 1 | jinka
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | victoria
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | hambantota
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | husavik
# Processing Record 29 of Set 1 | imbituba
# Processing Record 30 of Set 1 | mubi
# Processing Record 31 of Set 1 | huarmey
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | idar
# Processing Record 34 of Set 1 | aasiaat
# Processing Record 35 of Set 1 | adamovka
# Processing Record 36 of Set 1 | gurgan
# City not found. Skipping...
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | opuwo
# Processing Record 39 of Set 1 | bambous virieux
# Processing Record 40 of Set 1 | golkoy
# Processing Record 41 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 1 | bloemfontein
# Processing Record 43 of Set 1 | gouyave
# Processing Record 44 of Set 1 | shelburne
# Processing Record 45 of Set 1 | nouadhibou
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | san cristobal
# Processing Record 48 of Set 1 | kavaratti
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | ondangwa
# Processing Record 1 of Set 2 | nandyal
# Processing Record 2 of Set 2 | astana
# Processing Record 3 of Set 2 | saint-francois
# Processing Record 4 of Set 2 | la rioja
# Processing Record 5 of Set 2 | ilulissat
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | san miguel
# Processing Record 8 of Set 2 | berlevag
# Processing Record 9 of Set 2 | umm lajj
# Processing Record 10 of Set 2 | cayenne
# Processing Record 11 of Set 2 | chinsali
# Processing Record 12 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 13 of Set 2 | bengkulu
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | pathankot
# Processing Record 16 of Set 2 | vila velha
# Processing Record 17 of Set 2 | nanortalik
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | manglaur
# Processing Record 20 of Set 2 | kruisfontein
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | padang
# Processing Record 23 of Set 2 | tulu bolo
# Processing Record 24 of Set 2 | belmonte
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | meulaboh
# Processing Record 27 of Set 2 | saldanha
# Processing Record 28 of Set 2 | cubara
# Processing Record 29 of Set 2 | iqaluit
# Processing Record 30 of Set 2 | bangolo
# Processing Record 31 of Set 2 | nahariyya
# Processing Record 32 of Set 2 | harper
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 2 | grindavik
# Processing Record 36 of Set 2 | pajarito
# Processing Record 37 of Set 2 | abu dhabi
# Processing Record 38 of Set 2 | adrar
# Processing Record 39 of Set 2 | vwawa
# Processing Record 40 of Set 2 | clyde river
# Processing Record 41 of Set 2 | lebu
# Processing Record 42 of Set 2 | prainha
# Processing Record 43 of Set 2 | dromolaxia
# Processing Record 44 of Set 2 | linhares
# Processing Record 45 of Set 2 | lokosovo
# Processing Record 46 of Set 2 | chapais
# Processing Record 47 of Set 2 | mtsamboro
# Processing Record 48 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 49 of Set 2 | ornskoldsvik
# Processing Record 50 of Set 2 | debica
# Processing Record 1 of Set 3 | angoche
# Processing Record 2 of Set 3 | salalah
# Processing Record 3 of Set 3 | rawson
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | eshowe
# Processing Record 6 of Set 3 | hearst
# Processing Record 7 of Set 3 | ayagoz
# Processing Record 8 of Set 3 | dingle
# Processing Record 9 of Set 3 | birin
# Processing Record 10 of Set 3 | salihorsk
# Processing Record 11 of Set 3 | yozgat
# Processing Record 12 of Set 3 | saint-joseph
# Processing Record 13 of Set 3 | touros
# Processing Record 14 of Set 3 | vardo
# Processing Record 15 of Set 3 | margate
# Processing Record 16 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 17 of Set 3 | atasu
# Processing Record 18 of Set 3 | riyadh
# Processing Record 19 of Set 3 | cidreira
# Processing Record 20 of Set 3 | gerash
# Processing Record 21 of Set 3 | mahebourg
# Processing Record 22 of Set 3 | skibbereen
# Processing Record 23 of Set 3 | sao jose da coroa grande
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | torbay
# Processing Record 26 of Set 3 | port-gentil
# Processing Record 27 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 3 | canelones
# Processing Record 29 of Set 3 | rocha
# Processing Record 30 of Set 3 | mazyr
# Processing Record 31 of Set 3 | gat
# Processing Record 32 of Set 3 | mehamn
# Processing Record 33 of Set 3 | bulungu
# Processing Record 34 of Set 3 | rio grande
# Processing Record 35 of Set 3 | sao filipe
# Processing Record 36 of Set 3 | aquiraz
# Processing Record 37 of Set 3 | timra
# Processing Record 38 of Set 3 | indiaroba
# Processing Record 39 of Set 3 | nioro
# Processing Record 40 of Set 3 | grand gaube
# Processing Record 41 of Set 3 | hamilton
# Processing Record 42 of Set 3 | ust-tsilma
# Processing Record 43 of Set 3 | maniitsoq
# Processing Record 44 of Set 3 | turayf
# Processing Record 45 of Set 3 | sarandi
# Processing Record 46 of Set 3 | inhambane
# Processing Record 47 of Set 3 | marawi
# Processing Record 48 of Set 3 | zhezkazgan
# Processing Record 49 of Set 3 | gari
# Processing Record 50 of Set 3 | dutse
# Processing Record 1 of Set 4 | saint george
# Processing Record 2 of Set 4 | allapalli
# Processing Record 3 of Set 4 | qaqortoq
# Processing Record 4 of Set 4 | sakakah
# Processing Record 5 of Set 4 | odienne
# Processing Record 6 of Set 4 | nantucket
# Processing Record 7 of Set 4 | contamana
# Processing Record 8 of Set 4 | scarborough
# Processing Record 9 of Set 4 | forio
# Processing Record 10 of Set 4 | hofn
# Processing Record 11 of Set 4 | constanza
# Processing Record 12 of Set 4 | cockburn town
# Processing Record 13 of Set 4 | itaituba
# Processing Record 14 of Set 4 | yarada
# Processing Record 15 of Set 4 | moskovskiy
# Processing Record 16 of Set 4 | tshela
# Processing Record 17 of Set 4 | lerum
# Processing Record 18 of Set 4 | sao joao da barra
# Processing Record 19 of Set 4 | andarab
# City not found. Skipping...
# Processing Record 20 of Set 4 | taltal
# Processing Record 21 of Set 4 | puerto del rosario
# Processing Record 22 of Set 4 | santa rosa
# Processing Record 23 of Set 4 | mandera
# Processing Record 24 of Set 4 | faya
# Processing Record 25 of Set 4 | castro
# Processing Record 26 of Set 4 | khorixas
# Processing Record 27 of Set 4 | san joaquin
# Processing Record 28 of Set 4 | santa ana
# Processing Record 29 of Set 4 | requena
# Processing Record 30 of Set 4 | chortomlyk
# Processing Record 31 of Set 4 | mahanoro
# Processing Record 32 of Set 4 | agadir
# Processing Record 33 of Set 4 | srivardhan
# Processing Record 34 of Set 4 | mana
# Processing Record 35 of Set 4 | dudinka
# Processing Record 36 of Set 4 | george
# Processing Record 37 of Set 4 | kolvereid
# Processing Record 38 of Set 4 | takoradi
# Processing Record 39 of Set 4 | bandarbeyla
# Processing Record 40 of Set 4 | barcelos
# Processing Record 41 of Set 4 | nove mesto pod smrkem
# Processing Record 42 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 43 of Set 4 | krutikha
# Processing Record 44 of Set 4 | yarmouth
# Processing Record 45 of Set 4 | souillac
# Processing Record 46 of Set 4 | tornio
# Processing Record 47 of Set 4 | san juan
# Processing Record 48 of Set 4 | itarema
# Processing Record 49 of Set 4 | okoneshnikovo
# Processing Record 50 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 5 | guican
# Processing Record 2 of Set 5 | long beach
# Processing Record 3 of Set 5 | cassilandia
# Processing Record 4 of Set 5 | negombo
# Processing Record 5 of Set 5 | lagoa
# Processing Record 6 of Set 5 | cravo norte
# Processing Record 7 of Set 5 | burgos
# Processing Record 8 of Set 5 | baguanos
# Processing Record 9 of Set 5 | santa fe
# Processing Record 10 of Set 5 | nicoya
# Processing Record 11 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 5 | iberia
# Processing Record 13 of Set 5 | rio gallegos
# Processing Record 14 of Set 5 | minab
# Processing Record 15 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 5 | kanakapura
# Processing Record 17 of Set 5 | awbari
# Processing Record 18 of Set 5 | sao fidelis
# Processing Record 19 of Set 5 | kilindoni
# Processing Record 20 of Set 5 | belyy yar
# Processing Record 21 of Set 5 | richard toll
# City not found. Skipping...
# Processing Record 22 of Set 5 | eydhafushi
# Processing Record 23 of Set 5 | aswan
# Processing Record 24 of Set 5 | moussoro
# Processing Record 25 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 5 | erechim
# Processing Record 27 of Set 5 | doha
# Processing Record 28 of Set 5 | teguldet
# Processing Record 29 of Set 5 | muisne
# Processing Record 30 of Set 5 | tiznit
# Processing Record 31 of Set 5 | najran
# Processing Record 32 of Set 5 | paamiut
# Processing Record 33 of Set 5 | pemba
# Processing Record 34 of Set 5 | matay
# Processing Record 35 of Set 5 | zemetchino
# Processing Record 36 of Set 5 | visnes
# Processing Record 37 of Set 5 | creetown
# Processing Record 38 of Set 5 | coihueco
# Processing Record 39 of Set 5 | kadoma
# Processing Record 40 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 5 | iskateley
# Processing Record 42 of Set 5 | hit
# Processing Record 43 of Set 5 | lucera
# Processing Record 44 of Set 5 | carnarvon
# Processing Record 45 of Set 5 | rundu
# Processing Record 46 of Set 5 | oia
# Processing Record 47 of Set 5 | codrington
# Processing Record 48 of Set 5 | thompson
# Processing Record 49 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 50 of Set 5 | villa bruzual
# Processing Record 1 of Set 6 | naryan-mar
# Processing Record 2 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 6 | feijo
# Processing Record 4 of Set 6 | chateaudun
# Processing Record 5 of Set 6 | la asuncion
# Processing Record 6 of Set 6 | quatre cocos
# Processing Record 7 of Set 6 | dvinskoy
# Processing Record 8 of Set 6 | dorado
# Processing Record 9 of Set 6 | ouahigouya
# Processing Record 10 of Set 6 | koutiala
# Processing Record 11 of Set 6 | likasi
# Processing Record 12 of Set 6 | liwale
# Processing Record 13 of Set 6 | saint combs
# City not found. Skipping...
# Processing Record 14 of Set 6 | panama city
# Processing Record 15 of Set 6 | fasa
# Processing Record 16 of Set 6 | hobyo
# Processing Record 17 of Set 6 | boa vista
# Processing Record 18 of Set 6 | jumla
# Processing Record 19 of Set 6 | klaksvik
# Processing Record 20 of Set 6 | paralimni
# Processing Record 21 of Set 6 | mogadishu
# Processing Record 22 of Set 6 | puerto maldonado
# Processing Record 23 of Set 6 | porto velho
# Processing Record 24 of Set 6 | gusau
# Processing Record 25 of Set 6 | hurghada
# Processing Record 26 of Set 6 | puerto baquerizo moreno
# Processing Record 27 of Set 6 | trairi
# Processing Record 28 of Set 6 | bangangte
# Processing Record 29 of Set 6 | ritchie
# Processing Record 30 of Set 6 | gobabis
# Processing Record 31 of Set 6 | muros
# Processing Record 32 of Set 6 | kutum
# Processing Record 33 of Set 6 | ordu
# Processing Record 34 of Set 6 | makokou
# Processing Record 35 of Set 6 | yol
# Processing Record 36 of Set 6 | eqbaliyeh
# Processing Record 37 of Set 6 | painesville
# Processing Record 38 of Set 6 | coquimbo
# Processing Record 39 of Set 6 | sambava
# Processing Record 40 of Set 6 | lerwick
# Processing Record 41 of Set 6 | namibe
# Processing Record 42 of Set 6 | oswego
# Processing Record 43 of Set 6 | susangerd
# Processing Record 44 of Set 6 | chambas
# Processing Record 45 of Set 6 | cajati
# Processing Record 46 of Set 6 | masallatah
# Processing Record 47 of Set 6 | pimentel
# Processing Record 48 of Set 6 | alexandria
# Processing Record 49 of Set 6 | eyl
# Processing Record 50 of Set 6 | hellvik
# Processing Record 1 of Set 7 | caravelas
# Processing Record 2 of Set 7 | pitea
# Processing Record 3 of Set 7 | barra do garcas
# Processing Record 4 of Set 7 | silifke
# Processing Record 5 of Set 7 | tarko-sale
# Processing Record 6 of Set 7 | birnin kebbi
# Processing Record 7 of Set 7 | salisbury
# Processing Record 8 of Set 7 | punta gorda
# Processing Record 9 of Set 7 | aksu
# Processing Record 10 of Set 7 | narsaq
# Processing Record 11 of Set 7 | arnstadt
# Processing Record 12 of Set 7 | midland
# Processing Record 13 of Set 7 | aracuai
# Processing Record 14 of Set 7 | nortelandia
# Processing Record 15 of Set 7 | sao domingos do maranhao
# Processing Record 16 of Set 7 | jizan
# Processing Record 17 of Set 7 | marystown
# Processing Record 18 of Set 7 | miranda
# Processing Record 19 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 7 | methoni
# Processing Record 21 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 7 | lasa
# Processing Record 23 of Set 7 | snezhnogorsk
# Processing Record 24 of Set 7 | colares
# Processing Record 25 of Set 7 | hammerfest
# Processing Record 26 of Set 7 | monte cristi
# City not found. Skipping...
# Processing Record 27 of Set 7 | benghazi
# Processing Record 28 of Set 7 | honningsvag
# Processing Record 29 of Set 7 | kunya
# Processing Record 30 of Set 7 | antalaha
# Processing Record 31 of Set 7 | marapanim
# Processing Record 32 of Set 7 | comodoro rivadavia
# Processing Record 33 of Set 7 | talcahuano
# Processing Record 34 of Set 7 | murgud
# Processing Record 35 of Set 7 | tessalit
# Processing Record 36 of Set 7 | saint anthony
# Processing Record 37 of Set 7 | vyartsilya
# Processing Record 38 of Set 7 | mastic beach
# Processing Record 39 of Set 7 | helsinki
# Processing Record 40 of Set 7 | danilov
# Processing Record 41 of Set 7 | alekseyevka
# Processing Record 42 of Set 7 | kalmunai
# Processing Record 43 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 44 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 7 | yenagoa
# Processing Record 46 of Set 7 | yangambi
# Processing Record 47 of Set 7 | puerto colombia
# Processing Record 48 of Set 7 | laguna
# Processing Record 49 of Set 7 | kasongo-lunda
# Processing Record 50 of Set 7 | bor
# Processing Record 1 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 2 of Set 8 | abancay
# Processing Record 3 of Set 8 | kangaatsiaq
# Processing Record 4 of Set 8 | vila franca do campo
# Processing Record 5 of Set 8 | praia da vitoria
# Processing Record 6 of Set 8 | utete
# Processing Record 7 of Set 8 | sisimiut
# Processing Record 8 of Set 8 | perigueux
# Processing Record 9 of Set 8 | reconquista
# Processing Record 10 of Set 8 | grande-synthe
# Processing Record 11 of Set 8 | havre-saint-pierre
# Processing Record 12 of Set 8 | nalut
# Processing Record 13 of Set 8 | cannington
# Processing Record 14 of Set 8 | seabra
# Processing Record 15 of Set 8 | mineros
# Processing Record 16 of Set 8 | luderitz
# Processing Record 17 of Set 8 | boone
# Processing Record 18 of Set 8 | changji
# Processing Record 19 of Set 8 | sinjar
# Processing Record 20 of Set 8 | sehwan
# Processing Record 21 of Set 8 | barabinsk
# Processing Record 22 of Set 8 | barahona
# Processing Record 23 of Set 8 | piacabucu
# Processing Record 24 of Set 8 | leshukonskoye
# Processing Record 25 of Set 8 | fuglebjerg
# Processing Record 26 of Set 8 | verkhne-katunskoye
# City not found. Skipping...
# Processing Record 27 of Set 8 | matara
# Processing Record 28 of Set 8 | plettenberg bay
# Processing Record 29 of Set 8 | emirdag
# Processing Record 30 of Set 8 | oxford
# Processing Record 31 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 32 of Set 8 | axim
# Processing Record 33 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 34 of Set 8 | caconda
# Processing Record 35 of Set 8 | semnan
# Processing Record 36 of Set 8 | bathsheba
# Processing Record 37 of Set 8 | springdale
# Processing Record 38 of Set 8 | leh
# Processing Record 39 of Set 8 | nosy varika
# Processing Record 40 of Set 8 | yefira
# City not found. Skipping...
# Processing Record 41 of Set 8 | fonte boa
# Processing Record 42 of Set 8 | kombissiri
# Processing Record 43 of Set 8 | vestmanna
# Processing Record 44 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 45 of Set 8 | uetze
# Processing Record 46 of Set 8 | hualmay
# Processing Record 47 of Set 8 | manoel urbano
# Processing Record 48 of Set 8 | malakal
# Processing Record 49 of Set 8 | tabuk
# Processing Record 50 of Set 8 | pitimbu
# Processing Record 1 of Set 9 | mountmellick
# Processing Record 2 of Set 9 | lagos
# Processing Record 3 of Set 9 | sao miguel do araguaia
# Processing Record 4 of Set 9 | bodden town
# Processing Record 5 of Set 9 | sao gabriel da cachoeira
# Processing Record 6 of Set 9 | pisco
# Processing Record 7 of Set 9 | ondjiva
# Processing Record 8 of Set 9 | aksay
# Processing Record 9 of Set 9 | boulsa
# Processing Record 10 of Set 9 | muzhi
# Processing Record 11 of Set 9 | brae
# Processing Record 12 of Set 9 | tsabong
# Processing Record 13 of Set 9 | taoudenni
# Processing Record 14 of Set 9 | chiredzi
# Processing Record 15 of Set 9 | tela
# Processing Record 16 of Set 9 | aras
# Processing Record 17 of Set 9 | weligama
# Processing Record 18 of Set 9 | loja
# Processing Record 19 of Set 9 | sarh
# Processing Record 20 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 9 | njombe
# Processing Record 22 of Set 9 | pimenta bueno
# Processing Record 23 of Set 9 | vagur
# Processing Record 24 of Set 9 | tirukkoyilur
# Processing Record 25 of Set 9 | ngorongoro
# Processing Record 26 of Set 9 | kolyshley
# Processing Record 27 of Set 9 | kautokeino
# Processing Record 28 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 9 | ribnica
# Processing Record 30 of Set 9 | inongo
# Processing Record 31 of Set 9 | constitucion
# Processing Record 32 of Set 9 | kismayo
# Processing Record 33 of Set 9 | stutterheim
# Processing Record 34 of Set 9 | toktogul
# Processing Record 35 of Set 9 | vale da amoreira
# Processing Record 36 of Set 9 | disna
# Processing Record 37 of Set 9 | dunmore town
# Processing Record 38 of Set 9 | kazerun
# Processing Record 39 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 9 | sfantu gheorghe
# Processing Record 41 of Set 9 | sinop
# Processing Record 42 of Set 9 | birao
# Processing Record 43 of Set 9 | charleston
# Processing Record 44 of Set 9 | krasnoselkup
# Processing Record 45 of Set 9 | rincon
# Processing Record 46 of Set 9 | santander
# Processing Record 47 of Set 9 | point fortin
# Processing Record 48 of Set 9 | ancud
# Processing Record 49 of Set 9 | tome
# Processing Record 50 of Set 9 | thano bula khan
# City not found. Skipping...
# Processing Record 1 of Set 10 | hemnesberget
# Processing Record 2 of Set 10 | nicolas bravo
# Processing Record 3 of Set 10 | ardakan
# Processing Record 4 of Set 10 | concordia
# Processing Record 5 of Set 10 | kabo
# Processing Record 6 of Set 10 | massakory
# Processing Record 7 of Set 10 | benguela
# Processing Record 8 of Set 10 | vryburg
# Processing Record 9 of Set 10 | jalingo
# Processing Record 10 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 11 of Set 10 | mongoumba
# Processing Record 12 of Set 10 | san ramon de la nueva oran
# Processing Record 13 of Set 10 | bagotville
# Processing Record 14 of Set 10 | havelock
# Processing Record 15 of Set 10 | nuuk
# Processing Record 16 of Set 10 | moose factory
# Processing Record 17 of Set 10 | ejura
# Processing Record 18 of Set 10 | maridi
# Processing Record 19 of Set 10 | barra patuca
# Processing Record 20 of Set 10 | san antonio
# Processing Record 21 of Set 10 | aleksandrovka
# Processing Record 22 of Set 10 | loukhi
# Processing Record 23 of Set 10 | necochea
# Processing Record 24 of Set 10 | villamartin
# Processing Record 25 of Set 10 | vestmannaeyjar
# Processing Record 26 of Set 10 | thiruvananthapuram
# Processing Record 27 of Set 10 | gidam
# Processing Record 28 of Set 10 | olafsvik
# Processing Record 29 of Set 10 | chandler
# Processing Record 30 of Set 10 | litoral del san juan
# City not found. Skipping...
# Processing Record 31 of Set 10 | jalu
# Processing Record 32 of Set 10 | butembo
# Processing Record 33 of Set 10 | letnyaya stavka
# Processing Record 34 of Set 10 | marzuq
# Processing Record 35 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 10 | kita
# Processing Record 37 of Set 10 | kyritz
# Processing Record 38 of Set 10 | gamboma
# Processing Record 39 of Set 10 | foumbot
# Processing Record 40 of Set 10 | dmitrovsk-orlovskiy
# Processing Record 41 of Set 10 | manjacaze
# Processing Record 42 of Set 10 | beni
# Processing Record 43 of Set 10 | matagami
# Processing Record 44 of Set 10 | suslovo
# Processing Record 45 of Set 10 | bubaque
# Processing Record 46 of Set 10 | chicama
# Processing Record 47 of Set 10 | deh rawud
# City not found. Skipping...
# Processing Record 48 of Set 10 | obo
# Processing Record 49 of Set 10 | mayumba
# Processing Record 50 of Set 10 | tete
# Processing Record 1 of Set 11 | tambul
# City not found. Skipping...
# Processing Record 2 of Set 11 | buta
# Processing Record 3 of Set 11 | ville-marie
# Processing Record 4 of Set 11 | mount darwin
# Processing Record 5 of Set 11 | tocopilla
# Processing Record 6 of Set 11 | potchefstroom
# Processing Record 7 of Set 11 | ponta delgada
# Processing Record 8 of Set 11 | kalmar
# Processing Record 9 of Set 11 | inyonga
# Processing Record 10 of Set 11 | maragogi
# Processing Record 11 of Set 11 | hornepayne
# Processing Record 12 of Set 11 | omboue
# Processing Record 13 of Set 11 | beloha
# Processing Record 14 of Set 11 | elliot lake
# Processing Record 15 of Set 11 | eregli
# Processing Record 16 of Set 11 | korla
# Processing Record 17 of Set 11 | kachikau
# City not found. Skipping...
# Processing Record 18 of Set 11 | coihaique
# Processing Record 19 of Set 11 | stamsund
# City not found. Skipping...
# Processing Record 20 of Set 11 | gravdal
# Processing Record 21 of Set 11 | usinsk
# Processing Record 22 of Set 11 | abalak
# Processing Record 23 of Set 11 | jutai
# Processing Record 24 of Set 11 | tutoia
# Processing Record 25 of Set 11 | aulla
# Processing Record 26 of Set 11 | tayginka
# Processing Record 27 of Set 11 | isla mujeres
# Processing Record 28 of Set 11 | saint-augustin
# Processing Record 29 of Set 11 | khuzdar
# Processing Record 30 of Set 11 | gazli
# Processing Record 31 of Set 11 | nueva imperial
# Processing Record 32 of Set 11 | misratah
# Processing Record 33 of Set 11 | akureyri
# Processing Record 34 of Set 11 | katakwi
# Processing Record 35 of Set 11 | atar
# Processing Record 36 of Set 11 | babadag
# Processing Record 37 of Set 11 | kroderen
# City not found. Skipping...
# Processing Record 38 of Set 11 | gubskaya
# Processing Record 39 of Set 11 | sergiyevsk
# Processing Record 40 of Set 11 | road town
# Processing Record 41 of Set 11 | selestat
# Processing Record 42 of Set 11 | saladoblanco
# Processing Record 43 of Set 11 | shannon
# Processing Record 44 of Set 11 | aktau
# Processing Record 45 of Set 11 | itaberaba
# Processing Record 46 of Set 11 | buritis
# Processing Record 47 of Set 11 | hof
# Processing Record 48 of Set 11 | misrikh
# Processing Record 49 of Set 11 | keflavik
# Processing Record 50 of Set 11 | kingsport
# Processing Record 1 of Set 12 | zlobin
# Processing Record 2 of Set 12 | segou
# Processing Record 3 of Set 12 | abohar
# Processing Record 4 of Set 12 | maceio
# Processing Record 5 of Set 12 | intipuca
# Processing Record 6 of Set 12 | lewes
# Processing Record 7 of Set 12 | aden
# Processing Record 8 of Set 12 | burica
# City not found. Skipping...
# Processing Record 9 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 10 of Set 12 | saint-pierre
# Processing Record 11 of Set 12 | aguimes
# Processing Record 12 of Set 12 | roald
# Processing Record 13 of Set 12 | richards bay
# Processing Record 14 of Set 12 | bereda
# Processing Record 15 of Set 12 | pucallpa
# Processing Record 16 of Set 12 | rabo de peixe
# Processing Record 17 of Set 12 | itacoatiara
# Processing Record 18 of Set 12 | suoyarvi
# Processing Record 19 of Set 12 | monte alegre de sergipe
# Processing Record 20 of Set 12 | kargopol
# Processing Record 21 of Set 12 | timizart
# Processing Record 22 of Set 12 | saquena
# Processing Record 23 of Set 12 | suez
# Processing Record 24 of Set 12 | zadar
# Processing Record 25 of Set 12 | ailigandi
# Processing Record 26 of Set 12 | russkaya polyana
# Processing Record 27 of Set 12 | zemio
# Processing Record 28 of Set 12 | aviles
# Processing Record 29 of Set 12 | nsanje
# Processing Record 30 of Set 12 | chokwe
# Processing Record 31 of Set 12 | amancio
# City not found. Skipping...
# Processing Record 32 of Set 12 | general roca
# Processing Record 33 of Set 12 | tall kayf
# Processing Record 34 of Set 12 | bandar-e lengeh
# Processing Record 35 of Set 12 | cardiff
# Processing Record 36 of Set 12 | yar-sale
# Processing Record 37 of Set 12 | kovur
# Processing Record 38 of Set 12 | stanari
# Processing Record 39 of Set 12 | ozinki
# Processing Record 40 of Set 12 | arbazh
# Processing Record 41 of Set 12 | sao francisco
# Processing Record 42 of Set 12 | mudyuga
# City not found. Skipping...
# Processing Record 43 of Set 12 | zaraza
# Processing Record 44 of Set 12 | ngaoundere
# Processing Record 45 of Set 12 | killybegs
# Processing Record 46 of Set 12 | nyrob
# Processing Record 47 of Set 12 | kidal
# Processing Record 48 of Set 12 | gornopravdinsk
# Processing Record 49 of Set 12 | los llanos de aridane
# Processing Record 50 of Set 12 | wexford
# Processing Record 1 of Set 13 | iranshahr
# Processing Record 2 of Set 13 | idil
# Processing Record 3 of Set 13 | rosehearty
# Processing Record 4 of Set 13 | venado tuerto
# Processing Record 5 of Set 13 | nigel
# Processing Record 6 of Set 13 | duiwelskloof
# Processing Record 7 of Set 13 | chimbote
# Processing Record 8 of Set 13 | tchibanga
# Processing Record 9 of Set 13 | karatau
# Processing Record 10 of Set 13 | itamarandiba
# Processing Record 11 of Set 13 | pangnirtung
# Processing Record 12 of Set 13 | bilma
# Processing Record 13 of Set 13 | savonlinna
# Processing Record 14 of Set 13 | lohardaga
# Processing Record 15 of Set 13 | onega
# Processing Record 16 of Set 13 | choya
# Processing Record 17 of Set 13 | kabanga
# Processing Record 18 of Set 13 | mettur
# Processing Record 19 of Set 13 | valdivia
# Processing Record 20 of Set 13 | abeche
# Processing Record 21 of Set 13 | awjilah
# Processing Record 22 of Set 13 | aykino
# Processing Record 23 of Set 13 | mazagao
# Processing Record 24 of Set 13 | manakara
# Processing Record 25 of Set 13 | oktyabrskoye
# Processing Record 26 of Set 13 | new richmond
# Processing Record 27 of Set 13 | lugovoy
# Processing Record 28 of Set 13 | dakar
# Processing Record 29 of Set 13 | shahdol
# Processing Record 30 of Set 13 | rubio
# Processing Record 31 of Set 13 | sinnamary
# Processing Record 32 of Set 13 | kathmandu
# Processing Record 33 of Set 13 | sioux lookout
# Processing Record 34 of Set 13 | pomabamba
# Processing Record 35 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 36 of Set 13 | rokytne
# Processing Record 37 of Set 13 | zelenogorskiy
# Processing Record 38 of Set 13 | chipata
# Processing Record 39 of Set 13 | desaguadero
# Processing Record 40 of Set 13 | nanyamba
# Processing Record 41 of Set 13 | isparta
# Processing Record 42 of Set 13 | kesinga
# Processing Record 43 of Set 13 | san ramon
# Processing Record 44 of Set 13 | mahajanga
# Processing Record 45 of Set 13 | zapolyarnyy
# Processing Record 46 of Set 13 | halmstad
# Processing Record 47 of Set 13 | derzhavinsk
# Processing Record 48 of Set 13 | praia
# Processing Record 49 of Set 13 | kharp
# Processing Record 50 of Set 13 | pokhara
# Processing Record 1 of Set 14 | cruzeiro do sul
# Processing Record 2 of Set 14 | cahabon
# Processing Record 3 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 4 of Set 14 | bulawayo
# Processing Record 5 of Set 14 | panjab
# Processing Record 6 of Set 14 | karasjok
# Processing Record 7 of Set 14 | asyut
# Processing Record 8 of Set 14 | balad
# Processing Record 9 of Set 14 | bam
# Processing Record 10 of Set 14 | freeport
# Processing Record 11 of Set 14 | rio pomba
# Processing Record 12 of Set 14 | horqueta
# Processing Record 13 of Set 14 | zemaiciu naumiestis
# Processing Record 14 of Set 14 | valparaiso
# Processing Record 15 of Set 14 | goderich
# Processing Record 16 of Set 14 | guimar
# Processing Record 17 of Set 14 | jabinyanah
# Processing Record 18 of Set 14 | lebyazhye
# Processing Record 19 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 20 of Set 14 | pandamatenga
# Processing Record 21 of Set 14 | cimislia
# Processing Record 22 of Set 14 | pervomayskoye
# Processing Record 23 of Set 14 | ouallam
# Processing Record 24 of Set 14 | gaoual
# Processing Record 25 of Set 14 | ustka
# Processing Record 26 of Set 14 | pocone
# Processing Record 27 of Set 14 | yaksatovo
# Processing Record 28 of Set 14 | sussex
# Processing Record 29 of Set 14 | bingol
# Processing Record 30 of Set 14 | ostersund
# Processing Record 31 of Set 14 | catamarca
# Processing Record 32 of Set 14 | kriel
# Processing Record 33 of Set 14 | oranjemund
# Processing Record 34 of Set 14 | pergamino
# Processing Record 35 of Set 14 | kabalo
# Processing Record 36 of Set 14 | presidencia roque saenz pena
# Processing Record 37 of Set 14 | kasra
# City not found. Skipping...
# Processing Record 38 of Set 14 | beterou
# Processing Record 39 of Set 14 | georgiyevka
# Processing Record 40 of Set 14 | narasannapeta
# Processing Record 41 of Set 14 | shalakusha
# Processing Record 42 of Set 14 | akonolinga
# Processing Record 43 of Set 14 | arvika
# Processing Record 44 of Set 14 | inirida
# Processing Record 45 of Set 14 | thohoyandou
# Processing Record 46 of Set 14 | sipe sipe
# Processing Record 47 of Set 14 | bahia honda
# Processing Record 48 of Set 14 | abu kamal
# Processing Record 49 of Set 14 | chingirlau
# Processing Record 50 of Set 14 | sur
# Processing Record 1 of Set 15 | beyneu
# Processing Record 2 of Set 15 | biskamzha
# Processing Record 3 of Set 15 | corner brook
# Processing Record 4 of Set 15 | ostrovnoy
# Processing Record 5 of Set 15 | niono
# Processing Record 6 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 7 of Set 15 | tucuma
# Processing Record 8 of Set 15 | lixourion
# Processing Record 9 of Set 15 | mumford
# Processing Record 10 of Set 15 | marigot
# Processing Record 11 of Set 15 | joshimath
# Processing Record 12 of Set 15 | bria
# Processing Record 13 of Set 15 | hashtrud
# Processing Record 14 of Set 15 | cozumel
# Processing Record 15 of Set 15 | kodinar
# Processing Record 16 of Set 15 | diffa
# Processing Record 17 of Set 15 | pand
# Processing Record 18 of Set 15 | skjervoy
# Processing Record 19 of Set 15 | hlobyne
# Processing Record 20 of Set 15 | sawakin
# Processing Record 21 of Set 15 | clarksburg
# Processing Record 22 of Set 15 | uruzgan
# Processing Record 23 of Set 15 | charlestown
# Processing Record 24 of Set 15 | damghan
# Processing Record 25 of Set 15 | rebrikha
# Processing Record 26 of Set 15 | gangapur
# Processing Record 27 of Set 15 | vangaindrano
# Processing Record 28 of Set 15 | upata
# Processing Record 29 of Set 15 | andenes
# Processing Record 30 of Set 15 | nador
# Processing Record 31 of Set 15 | inta
# Processing Record 32 of Set 15 | aiani
# Processing Record 33 of Set 15 | blacksburg
# Processing Record 34 of Set 15 | priladozhskiy
# Processing Record 35 of Set 15 | kalomo
# City not found. Skipping...
# Processing Record 36 of Set 15 | holme
# Processing Record 37 of Set 15 | pedasi
# Processing Record 38 of Set 15 | ginir
# Processing Record 39 of Set 15 | prado
# Processing Record 40 of Set 15 | ribeira brava
# Processing Record 41 of Set 15 | gambo
# Processing Record 42 of Set 15 | baie-comeau
# Processing Record 43 of Set 15 | janow lubelski
# Processing Record 44 of Set 15 | tortoli
# Processing Record 45 of Set 15 | carutapera
# Processing Record 46 of Set 15 | kibondo
# Processing Record 47 of Set 15 | walvis bay
# Processing Record 48 of Set 15 | kathu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Ushuaia -54.8000 -68.3000     46.06        53         100       13.80
# 1   Kontagora  10.3999   5.4695     76.08        68          33        3.85
# 2  Bredasdorp -34.5322  20.0403     61.63        35           9        5.82
# 3     Qaanaaq  77.4840 -69.3632     29.14        93         100        4.25
# 4        Chuy -33.6971 -53.4616     53.17        94          70        4.90
#
#   Country Current Description
# 0      AR     overcast clouds
# 1      NG    scattered clouds
# 2      ZA           clear sky
# 3      GL     overcast clouds
# 4      UY       broken clouds

# %%
new_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df = new_df
city_data_df
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000 -68.3000     46.06        53         100
# 1     Kontagora      NG  10.3999   5.4695     76.08        68          33
# 2    Bredasdorp      ZA -34.5322  20.0403     61.63        35           9
# 3       Qaanaaq      GL  77.4840 -69.3632     29.14        93         100
# 4          Chuy      UY -33.6971 -53.4616     53.17        94          70
# ..          ...     ...      ...      ...       ...       ...         ...
# 686     Tortoli      IT  39.9256   9.6572     72.03        49         100
# 687  Carutapera      BR  -1.1950 -46.0200     74.19        93         100
# 688     Kibondo      TZ  -3.5864  30.7203     56.23        89          21
# 689  Walvis Bay      NA -22.9575  14.5053     69.10        31           0
# 690       Kathu      TH   7.9178  98.3332     85.75        86          98
#
#      Wind Speed Current Description
# 0         13.80     overcast clouds
# 1          3.85    scattered clouds
# 2          5.82           clear sky
# 3          4.25     overcast clouds
# 4          4.90       broken clouds
# ..          ...                 ...
# 686        6.20     overcast clouds
# 687        3.71     overcast clouds
# 688        1.54          few clouds
# 689       11.61           clear sky
# 690        4.18     overcast clouds
#
# [691 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
