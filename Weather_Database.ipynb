# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities=[]

# ID the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
## Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b86ed79d889c181e845cf1b8664d00bb

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Ceate an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | chicama
# Processing Record 3 of Set 1 | roald
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | mar del plata
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 1 | dingle
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | merrill
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | klaksvik
# Processing Record 14 of Set 1 | komsomolskiy
# Processing Record 15 of Set 1 | coihaique
# Processing Record 16 of Set 1 | chuy
# Processing Record 17 of Set 1 | korablino
# Processing Record 18 of Set 1 | altay
# Processing Record 19 of Set 1 | narsaq
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | geraldton
# Processing Record 22 of Set 1 | desterro
# Processing Record 23 of Set 1 | lasa
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | malanje
# Processing Record 28 of Set 1 | mehamn
# Processing Record 29 of Set 1 | colmenar viejo
# Processing Record 30 of Set 1 | cayenne
# Processing Record 31 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 1 | guia lopes da laguna
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | ginda
# Processing Record 35 of Set 1 | vila franca do campo
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | leh
# Processing Record 38 of Set 1 | carnot
# Processing Record 39 of Set 1 | cananeia
# Processing Record 40 of Set 1 | penzance
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | teguldet
# Processing Record 43 of Set 1 | saint-denis
# Processing Record 44 of Set 1 | san andres
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | morros
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | kruisfontein
# Processing Record 3 of Set 2 | porto novo
# Processing Record 4 of Set 2 | thinadhoo
# Processing Record 5 of Set 2 | gewane
# Processing Record 6 of Set 2 | souillac
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | eyl
# Processing Record 9 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 2 | natal
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 2 | ilhabela
# Processing Record 14 of Set 2 | llandrindod wells
# Processing Record 15 of Set 2 | aktanysh
# Processing Record 16 of Set 2 | mumford
# Processing Record 17 of Set 2 | aasiaat
# Processing Record 18 of Set 2 | rahatgarh
# Processing Record 19 of Set 2 | meulaboh
# Processing Record 20 of Set 2 | calabozo
# Processing Record 21 of Set 2 | vardo
# Processing Record 22 of Set 2 | piacabucu
# Processing Record 23 of Set 2 | bud
# Processing Record 24 of Set 2 | svetlyy
# Processing Record 25 of Set 2 | ankazoabo
# Processing Record 26 of Set 2 | saldanha
# Processing Record 27 of Set 2 | lubango
# Processing Record 28 of Set 2 | sao filipe
# Processing Record 29 of Set 2 | hit
# Processing Record 30 of Set 2 | ust-tsilma
# Processing Record 31 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 32 of Set 2 | panama city
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | kibakwe
# Processing Record 35 of Set 2 | jibuti
# Processing Record 36 of Set 2 | torbay
# Processing Record 37 of Set 2 | parrita
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | faya
# Processing Record 40 of Set 2 | vila velha
# Processing Record 41 of Set 2 | andenes
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | barras
# Processing Record 44 of Set 2 | uarini
# Processing Record 45 of Set 2 | koyilandi
# City not found. Skipping...
# Processing Record 46 of Set 2 | boende
# Processing Record 47 of Set 2 | itarare
# Processing Record 48 of Set 2 | ostrovnoy
# Processing Record 49 of Set 2 | luena
# Processing Record 50 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 3 | belyy yar
# Processing Record 2 of Set 3 | kapuskasing
# Processing Record 3 of Set 3 | tazovskiy
# Processing Record 4 of Set 3 | agboville
# Processing Record 5 of Set 3 | nanortalik
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | luderitz
# Processing Record 8 of Set 3 | sambava
# Processing Record 9 of Set 3 | keetmanshoop
# Processing Record 10 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 11 of Set 3 | tambopata
# Processing Record 12 of Set 3 | sargatskoye
# Processing Record 13 of Set 3 | quatre cocos
# Processing Record 14 of Set 3 | muisne
# Processing Record 15 of Set 3 | edremit
# Processing Record 16 of Set 3 | geresk
# City not found. Skipping...
# Processing Record 17 of Set 3 | sao joao da barra
# Processing Record 18 of Set 3 | dharchula
# Processing Record 19 of Set 3 | alice town
# Processing Record 20 of Set 3 | mitchelstown
# Processing Record 21 of Set 3 | husavik
# Processing Record 22 of Set 3 | cuamba
# Processing Record 23 of Set 3 | aras
# Processing Record 24 of Set 3 | glace bay
# Processing Record 25 of Set 3 | japura
# Processing Record 26 of Set 3 | ambilobe
# Processing Record 27 of Set 3 | touros
# Processing Record 28 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 3 | pinos puente
# Processing Record 30 of Set 3 | presidencia roque saenz pena
# Processing Record 31 of Set 3 | boyabat
# Processing Record 32 of Set 3 | aleksandrovskoye
# Processing Record 33 of Set 3 | praia
# Processing Record 34 of Set 3 | cockburn town
# Processing Record 35 of Set 3 | awjilah
# Processing Record 36 of Set 3 | yomou
# Processing Record 37 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 3 | turka
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | upernavik
# Processing Record 41 of Set 3 | floro
# Processing Record 42 of Set 3 | yugo-kamskiy
# Processing Record 43 of Set 3 | morant bay
# Processing Record 44 of Set 3 | lagoa
# Processing Record 45 of Set 3 | ilulissat
# Processing Record 46 of Set 3 | gat
# Processing Record 47 of Set 3 | pisco
# Processing Record 48 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 3 | pulivendla
# Processing Record 50 of Set 3 | corinto
# Processing Record 1 of Set 4 | hofn
# Processing Record 2 of Set 4 | padang
# Processing Record 3 of Set 4 | farah
# Processing Record 4 of Set 4 | bathsheba
# Processing Record 5 of Set 4 | skovde
# City not found. Skipping...
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | vagur
# Processing Record 8 of Set 4 | caravelas
# Processing Record 9 of Set 4 | tamandare
# Processing Record 10 of Set 4 | salalah
# Processing Record 11 of Set 4 | pskov
# Processing Record 12 of Set 4 | usogorsk
# Processing Record 13 of Set 4 | benghazi
# Processing Record 14 of Set 4 | kolobrzeg
# Processing Record 15 of Set 4 | axim
# Processing Record 16 of Set 4 | neftcala
# Processing Record 17 of Set 4 | hualmay
# Processing Record 18 of Set 4 | kavaratti
# Processing Record 19 of Set 4 | misratah
# Processing Record 20 of Set 4 | amapa
# Processing Record 21 of Set 4 | beruwala
# Processing Record 22 of Set 4 | hambantota
# Processing Record 23 of Set 4 | obo
# Processing Record 24 of Set 4 | nevsehir
# Processing Record 25 of Set 4 | dolores
# Processing Record 26 of Set 4 | knysna
# Processing Record 27 of Set 4 | pangnirtung
# Processing Record 28 of Set 4 | tonk
# Processing Record 29 of Set 4 | belmonte
# Processing Record 30 of Set 4 | coquimbo
# Processing Record 31 of Set 4 | inverness
# Processing Record 32 of Set 4 | ketou
# Processing Record 33 of Set 4 | nkowakowa
# Processing Record 34 of Set 4 | cusuna
# Processing Record 35 of Set 4 | henties bay
# Processing Record 36 of Set 4 | rio grande
# Processing Record 37 of Set 4 | luanda
# Processing Record 38 of Set 4 | numan
# Processing Record 39 of Set 4 | marawi
# Processing Record 40 of Set 4 | oneonta
# Processing Record 41 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 4 | saint-pierre
# Processing Record 43 of Set 4 | ponta do sol
# Processing Record 44 of Set 4 | harper
# Processing Record 45 of Set 4 | codrington
# Processing Record 46 of Set 4 | santa cruz
# Processing Record 47 of Set 4 | asmara
# Processing Record 48 of Set 4 | ostersund
# Processing Record 49 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 4 | atar
# Processing Record 1 of Set 5 | valera
# Processing Record 2 of Set 5 | zhezkazgan
# Processing Record 3 of Set 5 | farafangana
# Processing Record 4 of Set 5 | saint george
# Processing Record 5 of Set 5 | shush
# Processing Record 6 of Set 5 | warrington
# Processing Record 7 of Set 5 | saint-augustin
# Processing Record 8 of Set 5 | muyuka
# Processing Record 9 of Set 5 | boras
# Processing Record 10 of Set 5 | longyearbyen
# Processing Record 11 of Set 5 | melnikovo
# Processing Record 12 of Set 5 | ayios matthaios
# City not found. Skipping...
# Processing Record 13 of Set 5 | clyde river
# Processing Record 14 of Set 5 | le pradet
# Processing Record 15 of Set 5 | mbala
# Processing Record 16 of Set 5 | tariba
# Processing Record 17 of Set 5 | jaciara
# Processing Record 18 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 5 | veraval
# Processing Record 20 of Set 5 | carutapera
# Processing Record 21 of Set 5 | tselinnoye
# Processing Record 22 of Set 5 | samdari
# Processing Record 23 of Set 5 | kumluca
# Processing Record 24 of Set 5 | nova olimpia
# Processing Record 25 of Set 5 | rio de jesus
# Processing Record 26 of Set 5 | san rafael
# Processing Record 27 of Set 5 | lephepe
# City not found. Skipping...
# Processing Record 28 of Set 5 | jiwani
# Processing Record 29 of Set 5 | lucapa
# Processing Record 30 of Set 5 | richards bay
# Processing Record 31 of Set 5 | berlevag
# Processing Record 32 of Set 5 | visnes
# Processing Record 33 of Set 5 | katiola
# Processing Record 34 of Set 5 | castro
# Processing Record 35 of Set 5 | ikongo
# Processing Record 36 of Set 5 | muros
# Processing Record 37 of Set 5 | paulo afonso
# Processing Record 38 of Set 5 | hearst
# Processing Record 39 of Set 5 | humberto de campos
# Processing Record 40 of Set 5 | mbacke
# City not found. Skipping...
# Processing Record 41 of Set 5 | halifax
# Processing Record 42 of Set 5 | dujuma
# City not found. Skipping...
# Processing Record 43 of Set 5 | eastlake
# Processing Record 44 of Set 5 | sinop
# Processing Record 45 of Set 5 | doha
# Processing Record 46 of Set 5 | sao jose da coroa grande
# Processing Record 47 of Set 5 | antofagasta
# Processing Record 48 of Set 5 | vilnius
# Processing Record 49 of Set 5 | muli
# Processing Record 50 of Set 5 | tweed
# Processing Record 1 of Set 6 | troy
# Processing Record 2 of Set 6 | dindori
# Processing Record 3 of Set 6 | sangerhausen
# Processing Record 4 of Set 6 | tanda
# Processing Record 5 of Set 6 | beloha
# Processing Record 6 of Set 6 | grand gaube
# Processing Record 7 of Set 6 | hayrabolu
# Processing Record 8 of Set 6 | santa marta
# Processing Record 9 of Set 6 | morlaix
# Processing Record 10 of Set 6 | irtyshskiy
# Processing Record 11 of Set 6 | boke
# Processing Record 12 of Set 6 | ikom
# Processing Record 13 of Set 6 | marzuq
# Processing Record 14 of Set 6 | gengenbach
# Processing Record 15 of Set 6 | sinnamary
# Processing Record 16 of Set 6 | jizan
# Processing Record 17 of Set 6 | nikel
# Processing Record 18 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 6 | katima mulilo
# Processing Record 20 of Set 6 | coreau
# Processing Record 21 of Set 6 | jalu
# Processing Record 22 of Set 6 | khandbari
# Processing Record 23 of Set 6 | khndzoresk
# Processing Record 24 of Set 6 | inhambane
# Processing Record 25 of Set 6 | louga
# Processing Record 26 of Set 6 | carnarvon
# Processing Record 27 of Set 6 | dwarka
# Processing Record 28 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 6 | portage
# Processing Record 31 of Set 6 | kita
# Processing Record 32 of Set 6 | shchelyayur
# City not found. Skipping...
# Processing Record 33 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 6 | margate
# Processing Record 35 of Set 6 | poptun
# Processing Record 36 of Set 6 | jutai
# Processing Record 37 of Set 6 | xuddur
# Processing Record 38 of Set 6 | chik
# Processing Record 39 of Set 6 | havelock
# Processing Record 40 of Set 6 | varna
# Processing Record 41 of Set 6 | cururupu
# Processing Record 42 of Set 6 | asbestos
# Processing Record 43 of Set 6 | impfondo
# Processing Record 44 of Set 6 | mana
# Processing Record 45 of Set 6 | plettenberg bay
# Processing Record 46 of Set 6 | brae
# Processing Record 47 of Set 6 | san juan bautista
# Processing Record 48 of Set 6 | los llanos de aridane
# Processing Record 49 of Set 6 | tabuk
# Processing Record 50 of Set 6 | woonsocket
# Processing Record 1 of Set 7 | krasnoshchekovo
# Processing Record 2 of Set 7 | saint anthony
# Processing Record 3 of Set 7 | kabalo
# Processing Record 4 of Set 7 | dasoguz
# Processing Record 5 of Set 7 | maceio
# Processing Record 6 of Set 7 | cap malheureux
# Processing Record 7 of Set 7 | bridlington
# Processing Record 8 of Set 7 | walvis bay
# Processing Record 9 of Set 7 | rocha
# Processing Record 10 of Set 7 | yazman
# Processing Record 11 of Set 7 | bay roberts
# Processing Record 12 of Set 7 | itupiranga
# Processing Record 13 of Set 7 | nuuk
# Processing Record 14 of Set 7 | pinheiro machado
# Processing Record 15 of Set 7 | iqaluit
# Processing Record 16 of Set 7 | gambela
# Processing Record 17 of Set 7 | encruzilhada do sul
# Processing Record 18 of Set 7 | tessalit
# Processing Record 19 of Set 7 | bocaiuva
# Processing Record 20 of Set 7 | gbarnga
# Processing Record 21 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 7 | kibondo
# Processing Record 23 of Set 7 | punalur
# Processing Record 24 of Set 7 | aktau
# Processing Record 25 of Set 7 | young
# Processing Record 26 of Set 7 | naryan-mar
# Processing Record 27 of Set 7 | sao felix do xingu
# Processing Record 28 of Set 7 | mocuba
# Processing Record 29 of Set 7 | praia da vitoria
# Processing Record 30 of Set 7 | rawson
# Processing Record 31 of Set 7 | karlskoga
# Processing Record 32 of Set 7 | kasempa
# Processing Record 33 of Set 7 | mogadishu
# Processing Record 34 of Set 7 | pocone
# Processing Record 35 of Set 7 | boffa
# Processing Record 36 of Set 7 | alamor
# Processing Record 37 of Set 7 | maralal
# Processing Record 38 of Set 7 | okitipupa
# Processing Record 39 of Set 7 | borovskoy
# Processing Record 40 of Set 7 | panjab
# Processing Record 41 of Set 7 | moiyabana
# City not found. Skipping...
# Processing Record 42 of Set 7 | dianopolis
# City not found. Skipping...
# Processing Record 43 of Set 7 | bela vista
# Processing Record 44 of Set 7 | rio bueno
# Processing Record 45 of Set 7 | madison
# Processing Record 46 of Set 7 | paamiut
# Processing Record 47 of Set 7 | lixourion
# Processing Record 48 of Set 7 | zelenoborskiy
# Processing Record 49 of Set 7 | tir pol
# City not found. Skipping...
# Processing Record 50 of Set 7 | adrar
# Processing Record 1 of Set 8 | comodoro rivadavia
# Processing Record 2 of Set 8 | prainha
# Processing Record 3 of Set 8 | acarau
# Processing Record 4 of Set 8 | maarianhamina
# Processing Record 5 of Set 8 | kovur
# Processing Record 6 of Set 8 | montepuez
# Processing Record 7 of Set 8 | tonota
# Processing Record 8 of Set 8 | charleston
# Processing Record 9 of Set 8 | ancud
# Processing Record 10 of Set 8 | bilma
# Processing Record 11 of Set 8 | usinsk
# Processing Record 12 of Set 8 | tirumullaivasal
# Processing Record 13 of Set 8 | ippy
# Processing Record 14 of Set 8 | baiao
# Processing Record 15 of Set 8 | mindelo
# Processing Record 16 of Set 8 | monrovia
# Processing Record 17 of Set 8 | bandarbeyla
# Processing Record 18 of Set 8 | sakakah
# Processing Record 19 of Set 8 | panara
# Processing Record 20 of Set 8 | harlingen
# Processing Record 21 of Set 8 | constitucion
# Processing Record 22 of Set 8 | sukhumi
# Processing Record 23 of Set 8 | harer
# Processing Record 24 of Set 8 | krasnoarmeysk
# Processing Record 25 of Set 8 | nizwa
# Processing Record 26 of Set 8 | saint-lo
# Processing Record 27 of Set 8 | bubaque
# Processing Record 28 of Set 8 | korba
# Processing Record 29 of Set 8 | minchinabad
# Processing Record 30 of Set 8 | buckingham
# Processing Record 31 of Set 8 | sao raimundo das mangabeiras
# Processing Record 32 of Set 8 | tutin
# Processing Record 33 of Set 8 | valdivia
# Processing Record 34 of Set 8 | raudeberg
# Processing Record 35 of Set 8 | san cristobal
# Processing Record 36 of Set 8 | kotka
# Processing Record 37 of Set 8 | gamba
# Processing Record 38 of Set 8 | esna
# Processing Record 39 of Set 8 | nogent-le-rotrou
# Processing Record 40 of Set 8 | maposeni
# Processing Record 41 of Set 8 | quchan
# Processing Record 42 of Set 8 | le port
# Processing Record 43 of Set 8 | nalut
# Processing Record 44 of Set 8 | vestmannaeyjar
# Processing Record 45 of Set 8 | umm kaddadah
# Processing Record 46 of Set 8 | aksu
# Processing Record 47 of Set 8 | mukhtolovo
# Processing Record 48 of Set 8 | nouadhibou
# Processing Record 49 of Set 8 | varzea da palma
# Processing Record 50 of Set 8 | santa rosa
# Processing Record 1 of Set 9 | sistranda
# Processing Record 2 of Set 9 | agadez
# Processing Record 3 of Set 9 | banda aceh
# Processing Record 4 of Set 9 | pervoye maya
# Processing Record 5 of Set 9 | krasnoselkup
# Processing Record 6 of Set 9 | lyndon
# Processing Record 7 of Set 9 | gazanjyk
# Processing Record 8 of Set 9 | thilogne
# City not found. Skipping...
# Processing Record 9 of Set 9 | chimoio
# Processing Record 10 of Set 9 | letterkenny
# Processing Record 11 of Set 9 | watertown
# Processing Record 12 of Set 9 | staryy biser
# City not found. Skipping...
# Processing Record 13 of Set 9 | venice
# Processing Record 14 of Set 9 | inongo
# Processing Record 15 of Set 9 | kitgum
# Processing Record 16 of Set 9 | aljustrel
# Processing Record 17 of Set 9 | omboue
# Processing Record 18 of Set 9 | rio gallegos
# Processing Record 19 of Set 9 | xai-xai
# Processing Record 20 of Set 9 | tabas
# Processing Record 21 of Set 9 | methoni
# Processing Record 22 of Set 9 | umm lajj
# Processing Record 23 of Set 9 | santa lucia
# Processing Record 24 of Set 9 | papayal
# Processing Record 25 of Set 9 | paracatu
# Processing Record 26 of Set 9 | arlit
# Processing Record 27 of Set 9 | qabis
# City not found. Skipping...
# Processing Record 28 of Set 9 | sabha
# Processing Record 29 of Set 9 | abu zabad
# Processing Record 30 of Set 9 | yenagoa
# Processing Record 31 of Set 9 | olinda
# Processing Record 32 of Set 9 | higuey
# City not found. Skipping...
# Processing Record 33 of Set 9 | mahabad
# Processing Record 34 of Set 9 | springbok
# Processing Record 35 of Set 9 | namibe
# Processing Record 36 of Set 9 | sakaraha
# Processing Record 37 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 38 of Set 9 | caceres
# Processing Record 39 of Set 9 | visby
# Processing Record 40 of Set 9 | jumla
# Processing Record 41 of Set 9 | carcassonne
# Processing Record 42 of Set 9 | columbus
# Processing Record 43 of Set 9 | chimbote
# Processing Record 44 of Set 9 | maltahohe
# Processing Record 45 of Set 9 | ormara
# Processing Record 46 of Set 9 | micheweni
# Processing Record 47 of Set 9 | moshenskoye
# Processing Record 48 of Set 9 | oksfjord
# Processing Record 49 of Set 9 | calvinia
# Processing Record 50 of Set 9 | chapais
# Processing Record 1 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 2 of Set 10 | albanel
# Processing Record 3 of Set 10 | sztum
# Processing Record 4 of Set 10 | neustadt
# Processing Record 5 of Set 10 | beira
# Processing Record 6 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 7 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 10 | marica
# Processing Record 9 of Set 10 | guelengdeng
# City not found. Skipping...
# Processing Record 10 of Set 10 | havoysund
# Processing Record 11 of Set 10 | brasilia de minas
# Processing Record 12 of Set 10 | teya
# Processing Record 13 of Set 10 | saint-louis
# Processing Record 14 of Set 10 | mehran
# Processing Record 15 of Set 10 | kuri
# Processing Record 16 of Set 10 | gao
# Processing Record 17 of Set 10 | kindu
# Processing Record 18 of Set 10 | olafsvik
# Processing Record 19 of Set 10 | port-cartier
# Processing Record 20 of Set 10 | careiro da varzea
# Processing Record 21 of Set 10 | khromtau
# Processing Record 22 of Set 10 | gayeri
# Processing Record 23 of Set 10 | bahia blanca
# Processing Record 24 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 25 of Set 10 | lagos
# Processing Record 26 of Set 10 | maragogi
# Processing Record 27 of Set 10 | tabarqah
# City not found. Skipping...
# Processing Record 28 of Set 10 | saint combs
# City not found. Skipping...
# Processing Record 29 of Set 10 | urambo
# Processing Record 30 of Set 10 | metehara
# City not found. Skipping...
# Processing Record 31 of Set 10 | puerto leguizamo
# Processing Record 32 of Set 10 | acton vale
# Processing Record 33 of Set 10 | asfi
# Processing Record 34 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 35 of Set 10 | nantucket
# Processing Record 36 of Set 10 | sokoni
# Processing Record 37 of Set 10 | abrau-dyurso
# Processing Record 38 of Set 10 | pital
# Processing Record 39 of Set 10 | tocopilla
# Processing Record 40 of Set 10 | angoche
# Processing Record 41 of Set 10 | talnakh
# Processing Record 42 of Set 10 | thompson
# Processing Record 43 of Set 10 | manakara
# Processing Record 44 of Set 10 | gornopravdinsk
# Processing Record 45 of Set 10 | odweyne
# Processing Record 46 of Set 10 | oranjemund
# Processing Record 47 of Set 10 | korla
# Processing Record 48 of Set 10 | camabatela
# Processing Record 49 of Set 10 | urumqi
# Processing Record 50 of Set 10 | sidhi
# Processing Record 1 of Set 11 | darovskoy
# Processing Record 2 of Set 11 | gbadolite
# Processing Record 3 of Set 11 | stephenville
# Processing Record 4 of Set 11 | taoudenni
# Processing Record 5 of Set 11 | riyadh
# Processing Record 6 of Set 11 | puerto del rosario
# Processing Record 7 of Set 11 | maues
# Processing Record 8 of Set 11 | omaruru
# Processing Record 9 of Set 11 | baherden
# Processing Record 10 of Set 11 | narasannapeta
# Processing Record 11 of Set 11 | liverpool
# Processing Record 12 of Set 11 | medvezhyegorsk
# Processing Record 13 of Set 11 | itarema
# Processing Record 14 of Set 11 | gopinathpur
# Processing Record 15 of Set 11 | general roca
# Processing Record 16 of Set 11 | guntakal
# Processing Record 17 of Set 11 | shenkursk
# Processing Record 18 of Set 11 | bosansko grahovo
# Processing Record 19 of Set 11 | turbat
# Processing Record 20 of Set 11 | zeerust
# Processing Record 21 of Set 11 | la dolorita
# Processing Record 22 of Set 11 | millau
# Processing Record 23 of Set 11 | nueve de julio
# Processing Record 24 of Set 11 | port-gentil
# Processing Record 25 of Set 11 | nekhayevskiy
# Processing Record 26 of Set 11 | colares
# Processing Record 27 of Set 11 | qandahar
# City not found. Skipping...
# Processing Record 28 of Set 11 | sembe
# Processing Record 29 of Set 11 | saraland
# Processing Record 30 of Set 11 | oksbol
# Processing Record 31 of Set 11 | kjollefjord
# Processing Record 32 of Set 11 | mkushi
# Processing Record 33 of Set 11 | sur
# Processing Record 34 of Set 11 | kamina
# Processing Record 35 of Set 11 | concord
# Processing Record 36 of Set 11 | ugoofaaru
# Processing Record 37 of Set 11 | polyarnyy
# Processing Record 38 of Set 11 | rtishchevo
# Processing Record 39 of Set 11 | rundu
# Processing Record 40 of Set 11 | schenectady
# Processing Record 41 of Set 11 | bereznik
# Processing Record 42 of Set 11 | pipri
# Processing Record 43 of Set 11 | beyneu
# Processing Record 44 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 11 | moengo
# Processing Record 46 of Set 11 | osterburg
# Processing Record 47 of Set 11 | tanem
# Processing Record 48 of Set 11 | varkkallai
# Processing Record 49 of Set 11 | quattro castella
# Processing Record 50 of Set 11 | vestmanna
# Processing Record 1 of Set 12 | antalaha
# Processing Record 2 of Set 12 | kariba
# Processing Record 3 of Set 12 | molina
# Processing Record 4 of Set 12 | mbandaka
# Processing Record 5 of Set 12 | fomboni
# Processing Record 6 of Set 12 | bitlis
# Processing Record 7 of Set 12 | pervomayskiy
# Processing Record 8 of Set 12 | salinopolis
# Processing Record 9 of Set 12 | zig
# Processing Record 10 of Set 12 | tutoia
# Processing Record 11 of Set 12 | orsha
# Processing Record 12 of Set 12 | laguna
# Processing Record 13 of Set 12 | bahia honda
# Processing Record 14 of Set 12 | jablah
# Processing Record 15 of Set 12 | onega
# Processing Record 16 of Set 12 | batie
# Processing Record 17 of Set 12 | capreol
# Processing Record 18 of Set 12 | itapage
# Processing Record 19 of Set 12 | kondinskoye
# Processing Record 20 of Set 12 | dudinka
# Processing Record 21 of Set 12 | plyussa
# Processing Record 22 of Set 12 | fernandopolis
# Processing Record 23 of Set 12 | tamayo
# Processing Record 24 of Set 12 | mirnyy
# Processing Record 25 of Set 12 | balkanabat
# Processing Record 26 of Set 12 | roros
# Processing Record 27 of Set 12 | burica
# City not found. Skipping...
# Processing Record 28 of Set 12 | chaumont
# Processing Record 29 of Set 12 | safwah
# City not found. Skipping...
# Processing Record 30 of Set 12 | asosa
# Processing Record 31 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 32 of Set 12 | ladnun
# Processing Record 33 of Set 12 | kuusamo
# Processing Record 34 of Set 12 | abnub
# Processing Record 35 of Set 12 | zomin
# Processing Record 36 of Set 12 | sardinata
# Processing Record 37 of Set 12 | aksarka
# Processing Record 38 of Set 12 | doka
# Processing Record 39 of Set 12 | oussouye
# Processing Record 40 of Set 12 | maputo
# Processing Record 41 of Set 12 | vaikam
# Processing Record 42 of Set 12 | limoges
# Processing Record 43 of Set 12 | oranjestad
# Processing Record 44 of Set 12 | machhiwara
# Processing Record 45 of Set 12 | goya
# Processing Record 46 of Set 12 | carupano
# Processing Record 47 of Set 12 | negombo
# Processing Record 48 of Set 12 | porto walter
# Processing Record 49 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 50 of Set 12 | borama
# City not found. Skipping...
# Processing Record 1 of Set 13 | abdulino
# Processing Record 2 of Set 13 | kalmunai
# Processing Record 3 of Set 13 | kasongo-lunda
# Processing Record 4 of Set 13 | zambezi
# Processing Record 5 of Set 13 | ndele
# Processing Record 6 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 7 of Set 13 | abu samrah
# Processing Record 8 of Set 13 | mangai
# Processing Record 9 of Set 13 | mecca
# Processing Record 10 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 13 | biritiba-mirim
# Processing Record 12 of Set 13 | mao
# Processing Record 13 of Set 13 | bayir
# Processing Record 14 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 15 of Set 13 | hobyo
# Processing Record 16 of Set 13 | lima
# Processing Record 17 of Set 13 | virginia beach
# Processing Record 18 of Set 13 | chapleau
# Processing Record 19 of Set 13 | matay
# Processing Record 20 of Set 13 | karwar
# Processing Record 21 of Set 13 | loznica
# Processing Record 22 of Set 13 | maniitsoq
# Processing Record 23 of Set 13 | mandera
# Processing Record 24 of Set 13 | buta
# Processing Record 25 of Set 13 | sao gabriel da cachoeira
# Processing Record 26 of Set 13 | mossendjo
# Processing Record 27 of Set 13 | necochea
# Processing Record 28 of Set 13 | zaranj
# Processing Record 29 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 13 | tsumeb
# Processing Record 31 of Set 13 | sisimiut
# Processing Record 32 of Set 13 | taltal
# Processing Record 33 of Set 13 | olhao
# Processing Record 34 of Set 13 | lamu
# Processing Record 35 of Set 13 | bell ville
# Processing Record 36 of Set 13 | edd
# Processing Record 37 of Set 13 | sept-iles
# Processing Record 38 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 13 | grindavik
# Processing Record 40 of Set 13 | longido
# Processing Record 41 of Set 13 | clarence town
# Processing Record 42 of Set 13 | turukhansk
# Processing Record 43 of Set 13 | safidon
# Processing Record 44 of Set 13 | bloemfontein
# Processing Record 45 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 46 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 47 of Set 13 | tarko-sale
# Processing Record 48 of Set 13 | tsiroanomandidy
# Processing Record 49 of Set 13 | sarab
# Processing Record 50 of Set 13 | matrei
# City not found. Skipping...
# Processing Record 1 of Set 14 | baghdad
# Processing Record 2 of Set 14 | ciudad bolivar
# Processing Record 3 of Set 14 | matsanga
# City not found. Skipping...
# Processing Record 4 of Set 14 | waddan
# Processing Record 5 of Set 14 | paragominas
# Processing Record 6 of Set 14 | nagaur
# Processing Record 7 of Set 14 | baillif
# Processing Record 8 of Set 14 | oriximina
# Processing Record 9 of Set 14 | igrim
# Processing Record 10 of Set 14 | odienne
# Processing Record 11 of Set 14 | irmo
# Processing Record 12 of Set 14 | harindanga
# Processing Record 13 of Set 14 | tiznit
# Processing Record 14 of Set 14 | nouakchott
# Processing Record 15 of Set 14 | viloco
# Processing Record 16 of Set 14 | parana
# Processing Record 17 of Set 14 | artyom
# Processing Record 18 of Set 14 | mahibadhoo
# Processing Record 19 of Set 14 | folldal
# Processing Record 20 of Set 14 | westport
# Processing Record 21 of Set 14 | media luna
# Processing Record 22 of Set 14 | jawhar
# Processing Record 23 of Set 14 | zomba
# Processing Record 24 of Set 14 | nebolchi
# Processing Record 25 of Set 14 | campobasso
# Processing Record 26 of Set 14 | rosario
# Processing Record 27 of Set 14 | rylsk
# Processing Record 28 of Set 14 | huarmey
# Processing Record 29 of Set 14 | mimoso do sul
# Processing Record 30 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 31 of Set 14 | mezen
# Processing Record 32 of Set 14 | mastic beach
# Processing Record 33 of Set 14 | kaka
# Processing Record 34 of Set 14 | platonovka
# Processing Record 35 of Set 14 | garowe
# Processing Record 36 of Set 14 | ulfborg
# Processing Record 37 of Set 14 | sarai mir
# Processing Record 38 of Set 14 | rabat
# Processing Record 39 of Set 14 | puyo
# Processing Record 40 of Set 14 | arroyo
# Processing Record 41 of Set 14 | bougouni
# Processing Record 42 of Set 14 | diffa
# Processing Record 43 of Set 14 | general pico
# Processing Record 44 of Set 14 | bolshaya glushitsa
# Processing Record 45 of Set 14 | koulamoutou
# Processing Record 46 of Set 14 | qeshm
# Processing Record 47 of Set 14 | chipinge
# Processing Record 48 of Set 14 | borba
# Processing Record 49 of Set 14 | paita
# Processing Record 50 of Set 14 | carauari
# Processing Record 1 of Set 15 | oskarshamn
# Processing Record 2 of Set 15 | coari
# Processing Record 3 of Set 15 | carepa
# Processing Record 4 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 5 of Set 15 | qarqin
# Processing Record 6 of Set 15 | thunder bay
# Processing Record 7 of Set 15 | savalou
# Processing Record 8 of Set 15 | kiruna
# Processing Record 9 of Set 15 | bodden town
# Processing Record 10 of Set 15 | hvide sande
# Processing Record 11 of Set 15 | puerto madryn
# Processing Record 12 of Set 15 | nisia floresta
# Processing Record 13 of Set 15 | goure
# Processing Record 14 of Set 15 | mola di bari
# Processing Record 15 of Set 15 | saint-michel-des-saints
# Processing Record 16 of Set 15 | makhinjauri
# Processing Record 17 of Set 15 | kutum
# Processing Record 18 of Set 15 | atasu
# Processing Record 19 of Set 15 | coello
# Processing Record 20 of Set 15 | point pleasant
# Processing Record 21 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 22 of Set 15 | turtkul
# City not found. Skipping...
# Processing Record 23 of Set 15 | chamba
# Processing Record 24 of Set 15 | saint-francois
# Processing Record 25 of Set 15 | boralday
# Processing Record 26 of Set 15 | gargalianoi
# Processing Record 27 of Set 15 | gedo
# Processing Record 28 of Set 15 | zabol
# Processing Record 29 of Set 15 | saint-joseph
# Processing Record 30 of Set 15 | sechura
# Processing Record 31 of Set 15 | libertador general san martin
# Processing Record 32 of Set 15 | maldonado
# Processing Record 33 of Set 15 | havre-saint-pierre
# Processing Record 34 of Set 15 | kemijarvi
# Processing Record 35 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 36 of Set 15 | alta floresta
# Processing Record 37 of Set 15 | shamary
# Processing Record 38 of Set 15 | araria
# Processing Record 39 of Set 15 | garavuti
# Processing Record 40 of Set 15 | burriana
# Processing Record 41 of Set 15 | mwene-ditu
# Processing Record 42 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 43 of Set 15 | boa vista
# Processing Record 44 of Set 15 | pimentel
# Processing Record 45 of Set 15 | rahimatpur
# Processing Record 46 of Set 15 | tete
# Processing Record 47 of Set 15 | robertsport
# Processing Record 48 of Set 15 | soyo
# Processing Record 49 of Set 15 | staritsa
# Processing Record 50 of Set 15 | aswan
# Processing Record 1 of Set 16 | fort-shevchenko
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Jamestown  42.0970 -79.2353     59.72        51           0        3.44
# 1    Chicama  -7.8447 -79.1469     59.54        85          97        6.08
# 2      Roald  62.5833   6.1333     46.33        93          22        3.44
# 3  Mahebourg -20.4081  57.7000     73.69        83          40        8.05
# 4  Hithadhoo  -0.6000  73.0833     82.26        71          86        3.20
#
#   Country Current Description
# 0      US           clear sky
# 1      PE     overcast clouds
# 2      NO          few clouds
# 3      MU    scattered clouds
# 4      MV     overcast clouds

# %%
new_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df = new_df
city_data_df
# Out:
#                 City Country      Lat      Lng  Max Temp  Humidity  \
# 0          Jamestown      US  42.0970 -79.2353     59.72        51
# 1            Chicama      PE  -7.8447 -79.1469     59.54        85
# 2              Roald      NO  62.5833   6.1333     46.33        93
# 3          Mahebourg      MU -20.4081  57.7000     73.69        83
# 4          Hithadhoo      MV  -0.6000  73.0833     82.26        71
# ..               ...     ...      ...      ...       ...       ...
# 678      Robertsport      LR   6.7533 -11.3686     78.44        82
# 679             Soyo      AO  -6.1349  12.3689     72.88        93
# 680         Staritsa      RU  56.5075  34.9354     57.54        71
# 681            Aswan      EG  24.0934  32.9070     85.30        20
# 682  Fort-Shevchenko      KZ  44.5086  50.2630     75.36        47
#
#      Cloudiness  Wind Speed Current Description
# 0             0        3.44           clear sky
# 1            97        6.08     overcast clouds
# 2            22        3.44          few clouds
# 3            40        8.05    scattered clouds
# 4            86        3.20     overcast clouds
# ..          ...         ...                 ...
# 678         100        3.40          light rain
# 679          20        6.22          few clouds
# 680          32        6.31    scattered clouds
# 681           0        5.75           clear sky
# 682          88        6.29     overcast clouds
#
# [683 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
